# %%
#importing packages that will be needed to test the data

# %%
import pandas as pd
import pandas as pd
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.stats import ttest_ind 
import matplotlib.pyplot as plt 
import seaborn as sns
import openpyxl

# %%
#importing the data I will be using

# %%
covid=pd.read_csv('Data/covid19vaccinesbycounty.csv')

# %%
#this is 10 rows of data to see some data a glance

# %%
covid.head(11)
# Out:
#      county administered_date  total_doses  cumulative_total_doses  \
# 0   Alameda        2020-01-05            0                       0
# 1   Alameda        2020-07-27            0                       0
# 2   Alameda        2020-07-29            0                       1
# 3   Alameda        2020-07-30            0                       1
# 4   Alameda        2020-07-31            0                       1
# 5   Alameda        2020-08-01            0                       1
# 6   Alameda        2020-08-02            0                       1
# 7   Alameda        2020-08-03            0                       1
# 8   Alameda        2020-08-04            0                       1
# 9   Alameda        2020-08-05            0                       1
# 10  Alameda        2020-08-06            0                       1
#
#     pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 0              0                        0              0
# ...

# %%
#Imported another dataset

# %%
county=pd.read_csv('Data/covid19vaccinesbycounty.csv')

# %%
doses=pd.read_csv('Data/covid19vaccinesadministeredbydemographics.csv')

# %%
doses.head()
# Out:
#   demographic_category demographic_value administered_date  total_doses  \
# 0            Age Group             18-49        2022-05-24         4691
# 1            Age Group             50-64        2022-05-24         9419
# 2            Age Group               65+        2022-05-24        14213
# 3            Age Group             12-17        2022-05-24         1144
# 4            Age Group              5-11        2022-05-24         2570
#
#    cumulative_total_doses  pfizer_doses  cumulative_pfizer_doses  \
# 0                34103581          2940                 20171196
# 1                17348656          5001                  9212374
# 2                16417987          6963                  7728306
# 3                 5414757          1141                  5398601
# 4                 2702236          2569                  2699203
#
#    moderna_doses  cumulative_moderna_doses  jj_doses  cumulative_jj_doses  \
# ...

# %%
pwd
# Out:
# '/Users/jin/Desktop/Final-Project-'

# %%
#i used the code concat to merge

# %%
covid2=pd.concat([covid,county,doses])

# %%
covid2.head(11)
# Out:
#      county administered_date  total_doses  cumulative_total_doses  \
# 0   Alameda        2020-01-05            0                       0
# 1   Alameda        2020-07-27            0                       0
# 2   Alameda        2020-07-29            0                       1
# 3   Alameda        2020-07-30            0                       1
# 4   Alameda        2020-07-31            0                       1
# 5   Alameda        2020-08-01            0                       1
# 6   Alameda        2020-08-02            0                       1
# 7   Alameda        2020-08-03            0                       1
# 8   Alameda        2020-08-04            0                       1
# 9   Alameda        2020-08-05            0                       1
# 10  Alameda        2020-08-06            0                       1
#
#     pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 0              0                        0              0
# ...

# %%
# inputing isnull code to see all data that has null

# %%
covid2.isnull().sum()
# Out:
# county                            11027
# administered_date                     0
# total_doses                           0
# cumulative_total_doses                0
# pfizer_doses                          0
# cumulative_pfizer_doses               0
# moderna_doses                         0
# cumulative_moderna_doses              0
# jj_doses                              0
# cumulative_jj_doses                   0
# partially_vaccinated                  0
# total_partially_vaccinated            0
# fully_vaccinated                      0
# cumulative_fully_vaccinated           0
# at_least_one_dose                     0
# cumulative_at_least_one_dose          0
# california_flag                   28955
# booster_recip_count                   0
# cumulative_booster_recip_count        0
# demographic_category              81220
# demographic_value                 81220
# booster_eligible_population       81220
# dtype: int64

# %%
#inputing notnull code to view data that has data

# %%
covid2.notnull().head()
# Out:
#    county  administered_date  total_doses  cumulative_total_doses  \
# 0    True               True         True                    True
# 1    True               True         True                    True
# 2    True               True         True                    True
# 3    True               True         True                    True
# 4    True               True         True                    True
#
#    pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 0          True                     True           True
# 1          True                     True           True
# 2          True                     True           True
# 3          True                     True           True
# 4          True                     True           True
#
#    cumulative_moderna_doses  jj_doses  cumulative_jj_doses  ...  \
# 0                      True      True                 True  ...
# 1                      True      True                 True  ...
# ...

# %%
covid2.shape
# Out:
# (92247, 22)

# %%
# this is 10 rows of the dataset with the missing data removed

# %%
covid2.head()
# Out:
#     county administered_date  total_doses  cumulative_total_doses  \
# 0  Alameda        2020-01-05            0                       0
# 1  Alameda        2020-07-27            0                       0
# 2  Alameda        2020-07-29            0                       1
# 3  Alameda        2020-07-30            0                       1
# 4  Alameda        2020-07-31            0                       1
#
#    pfizer_doses  cumulative_pfizer_doses  moderna_doses  \
# 0             0                        0              0
# 1             0                        0              0
# 2             0                        0              0
# 3             0                        0              0
# 4             0                        0              0
#
#    cumulative_moderna_doses  jj_doses  cumulative_jj_doses  ...  \
# 0                         0         0                    0  ...
# 1                         0         0                    0  ...
# ...

# %%
covid2.tail(20)
# Out:
#       county administered_date  total_doses  cumulative_total_doses  \
# 11007    NaN        2020-07-29            6                      11
# 11008    NaN        2020-07-29            2                       5
# 11009    NaN        2020-07-28            3                       5
# 11010    NaN        2020-07-28            3                       4
# 11011    NaN        2020-07-28            4                       5
# 11012    NaN        2020-07-28            2                       5
# 11013    NaN        2020-07-28            4                       5
# 11014    NaN        2020-07-28            1                       3
# 11015    NaN        2020-07-28            1                       1
# 11016    NaN        2020-07-27            1                       2
# 11017    NaN        2020-07-27            1                       1
# 11018    NaN        2020-07-27            1                       1
# 11019    NaN        2020-07-27            2                       3
# ...

# %%
#inputing info code to see column names and type of data (interger, object)

# %%
covid2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92247 entries, 0 to 11026
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   county                          81220 non-null  object
#  1   administered_date               92247 non-null  object
#  2   total_doses                     92247 non-null  int64
#  3   cumulative_total_doses          92247 non-null  int64
#  4   pfizer_doses                    92247 non-null  int64
#  5   cumulative_pfizer_doses         92247 non-null  int64
#  6   moderna_doses                   92247 non-null  int64
#  7   cumulative_moderna_doses        92247 non-null  int64
#  8   jj_doses                        92247 non-null  int64
#  9   cumulative_jj_doses             92247 non-null  int64
#  10  partially_vaccinated            92247 non-null  int64
#  11  total_partially_vaccinated      92247 non-null  int64
# ...

# %%
covid2.columns
# Out:
# Index(['county', 'administered_date', 'total_doses', 'cumulative_total_doses',
#        'pfizer_doses', 'cumulative_pfizer_doses', 'moderna_doses',
#        'cumulative_moderna_doses', 'jj_doses', 'cumulative_jj_doses',
#        'partially_vaccinated', 'total_partially_vaccinated',
#        'fully_vaccinated', 'cumulative_fully_vaccinated', 'at_least_one_dose',
#        'cumulative_at_least_one_dose', 'california_flag',
#        'booster_recip_count', 'cumulative_booster_recip_count',
#        'demographic_category', 'demographic_value',
#        'booster_eligible_population'],
#       dtype='object')

# %%
covid2.isnull().sum()
# Out:
# county                            11027
# administered_date                     0
# total_doses                           0
# cumulative_total_doses                0
# pfizer_doses                          0
# cumulative_pfizer_doses               0
# moderna_doses                         0
# cumulative_moderna_doses              0
# jj_doses                              0
# cumulative_jj_doses                   0
# partially_vaccinated                  0
# total_partially_vaccinated            0
# fully_vaccinated                      0
# cumulative_fully_vaccinated           0
# at_least_one_dose                     0
# cumulative_at_least_one_dose          0
# california_flag                   28955
# booster_recip_count                   0
# cumulative_booster_recip_count        0
# demographic_category              81220
# demographic_value                 81220
# booster_eligible_population       81220
# dtype: int64

# %%
covid2.head(20)
# Out:
#      county administered_date  total_doses  cumulative_total_doses  \
# 0   Alameda        2020-01-05            0                       0
# 1   Alameda        2020-07-27            0                       0
# 2   Alameda        2020-07-29            0                       1
# 3   Alameda        2020-07-30            0                       1
# 4   Alameda        2020-07-31            0                       1
# 5   Alameda        2020-08-01            0                       1
# 6   Alameda        2020-08-02            0                       1
# 7   Alameda        2020-08-03            0                       1
# 8   Alameda        2020-08-04            0                       1
# 9   Alameda        2020-08-05            0                       1
# 10  Alameda        2020-08-06            0                       1
# 11  Alameda        2020-08-07            0                       1
# 12  Alameda        2020-08-08            0                       1
# ...
